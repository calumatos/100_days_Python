# %% [markdown]
# ### Blackjack - Day 11
#
# #### RULES:
# Once all cards are drawn, whoever has a total closer to 21 than the dealer wins.
# If player’s hand and dealer’s hand have an equal value, it’s a tie.
#
#
# ############### Our Blackjack House Rules #####################
#
# - The deck is unlimited in size.
# - There are no jokers.
# - The Jack/Queen/King all count as 10.
# - The the Ace can count as 11 or 1.
# - Use the following list as the deck of cards: cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
# - The cards in the list have equal probability of being drawn.
# - Cards are not removed from the deck as they are drawn.
# - The computer is the dealer.

# %%
def play_game():
    logo = """
.------.            _     _            _    _            _    
|A_  _ |.          | |   | |          | |  (_)          | |   
|( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
| \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
|  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   < 
`-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\\
      |  \/ K|                            _/ |                
      `------'                           |__/           
"""
    print(logo)                

    def deal_card():
        '''Returns a random card from the deck'''
        import random
        cards = [11, 2, 3, 4, 5, 6, 7, 8, 9, 10, 10, 10, 10]
        dealed_card = random.choice(cards)
        return dealed_card

    user_cards = []
    computer_cards = []

    for i in range(2):
        user_cards.append(deal_card())
        computer_cards.append(deal_card())  

    def calculate_score(cards):
        '''Take a list of cards and return the score calculated from the cards'''
        if sum(cards) == 21 and len(cards) == 2:
            return 0
        elif 11 in cards and sum(cards) > 21:
            cards.remove(11)
            cards.append(1)
        return sum(cards)   

    def compare(user_score, computer_score):
        '''Compare the scores and return the results'''
        if user_score == computer_score:
            return "It's a draw"
        elif computer_score == 21:
            return "Computer has BLACKJACK, you lose"
        elif user_score == 21:
            return "BLACKJACK, you win!!!"
        elif user_score > 21:
            return "You went over. You lose."
        elif computer_score > 21:
            return "Computer went over. You win!!!"
        else:
            if user_score > computer_score:
                return "You win!"
            else:
                return "You lose."

    is_game_over = False
    while not is_game_over:
        user_score = calculate_score(user_cards)
        computer_score = calculate_score(computer_cards)
        print(f"Your cards: {user_cards}, current score: {user_score}.")
        print(f"Computer's first card: {computer_cards[0]}")

        if user_score == 0 or computer_score == 0 or user_score > 21:
            is_game_over = True
        else:
            user_answer = input("Type 'y' to get another card, type 'n' to pass: ").lower()
            if user_answer == "y":
                user_cards.append(deal_card())
            else: 
                is_game_over = True

    while computer_score != 0 and computer_score < 17:
        computer_cards.append(deal_card())
        computer_score = calculate_score(computer_cards)
    
    ### final results
    
    print("\n>>>>> RESULTS <<<<<")    
    print(f"\nYour final hand: {user_cards}, final score: {user_score}")  
    print(f"Computer's final hand: {computer_cards}, final score: {computer_score}")
    print(compare(user_score, computer_score))

# %%
### To start the game:
while input("Do you want to play a game of Blackjack? Type 'y' or 'n': ") == "y":
    play_game()
# Out:
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# Your cards: [8, 10], current score: 18.
# Computer's first card: 2
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [8, 10, 3], current score: 21.
# Computer's first card: 2
# Type 'y' to get another card, type 'n' to pass: n
#
# >>>>> RESULTS <<<<<
#
# Your final hand: [8, 10, 3], final score: 21
# Computer's final hand: [2, 10, 10], final score: 22
# BLACKJACK, you win!!!
# Do you want to play a game of Blackjack? Type 'y' or 'n': y
#
# .------.            _     _            _    _            _
# |A_  _ |.          | |   | |          | |  (_)          | |
# |( \/ ).-----.     | |__ | | __ _  ___| | ___  __ _  ___| | __
# | \  /|K /\  |     | '_ \| |/ _` |/ __| |/ / |/ _` |/ __| |/ /
# |  \/ | /  \ |     | |_) | | (_| | (__|   <| | (_| | (__|   <
# `-----| \  / |     |_.__/|_|\__,_|\___|_|\_\ |\__,_|\___|_|\_\
#       |  \/ K|                            _/ |
#       `------'                           |__/
#
# Your cards: [11, 4], current score: 15.
# Computer's first card: 7
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [4, 10, 1], current score: 15.
# Computer's first card: 7
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [4, 10, 1, 1], current score: 16.
# Computer's first card: 7
# Type 'y' to get another card, type 'n' to pass: y
# Your cards: [4, 10, 1, 1, 10], current score: 26.
# Computer's first card: 7
#
# >>>>> RESULTS <<<<<
#
# Your final hand: [4, 10, 1, 1, 10], final score: 26
# Computer's final hand: [7, 5, 1, 8], final score: 21
# Computer has BLACKJACK, you lose
# Do you want to play a game of Blackjack? Type 'y' or 'n': n
